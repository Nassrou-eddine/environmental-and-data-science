# %%
import pandas as pd

# %%
df = pd.read_csv('Plastic Waste Around the World.csv')
df
# Out:
#               Country  Total_Plastic_Waste_MT           Main_Sources  \
# 0               China                   59.08   Packaging_Industrial
# 1       United States                   42.02     Packaging_Consumer
# 2               India                   26.33         Consumer_Goods
# 3               Japan                    7.99  Packaging_Electronics
# 4             Germany                    6.28   Automotive_Packaging
# ..                ...                     ...                    ...
# 160  Marshall Islands                    0.01     Consumer_Packaging
# 161        Micronesia                    0.01     Consumer_Packaging
# 162             Palau                    0.01     Consumer_Packaging
# 163            Tuvalu                    0.01     Consumer_Packaging
# 164             Nauru                    0.01     Consumer_Packaging
#
#      Recycling_Rate  Per_Capita_Waste_KG Coastal_Waste_Risk
# 0              29.8                 41.2               High
# 1              32.1                127.5             Medium
# 2              11.5                 19.3               High
# 3              84.8                 63.2             Medium
# 4              56.1                 75.6                Low
# ..              ...                  ...                ...
# 160             1.8                168.5               High
# 161             1.5                 86.3               High
# 162            12.3                437.2               High
# 163             1.2                833.3               High
# 164             0.9                927.8               High
#
# [165 rows x 6 columns]

# %%
df.shape
# Out:
# (165, 6)

# %%
df.columns
# Out:
# Index(['Country', 'Total_Plastic_Waste_MT', 'Main_Sources', 'Recycling_Rate',
#        'Per_Capita_Waste_KG', 'Coastal_Waste_Risk'],
#       dtype='object')

# %%
df.head(10)
# Out:
#           Country  Total_Plastic_Waste_MT           Main_Sources  \
# 0           China                   59.08   Packaging_Industrial
# 1   United States                   42.02     Packaging_Consumer
# 2           India                   26.33         Consumer_Goods
# 3           Japan                    7.99  Packaging_Electronics
# 4         Germany                    6.28   Automotive_Packaging
# 5          Brazil                    5.96     Consumer_Packaging
# 6       Indonesia                    5.85         Food_Packaging
# 7          Russia                    5.84    Industrial_Consumer
# 8  United Kingdom                    5.03     Packaging_Consumer
# 9          France                    4.98     Packaging_Consumer
#
#    Recycling_Rate  Per_Capita_Waste_KG Coastal_Waste_Risk
# 0            29.8                 41.2               High
# 1            32.1                127.5             Medium
# 2            11.5                 19.3               High
# 3            84.8                 63.2             Medium
# 4            56.1                 75.6                Low
# 5             1.2                 28.1             Medium
# 6            11.8                 21.3          Very_High
# 7             5.6                 40.2             Medium
# 8            46.2                 74.3                Low
# 9            27.3                 73.1                Low

# %%
df.describe()
# Out:
#        Total_Plastic_Waste_MT  Recycling_Rate  Per_Capita_Waste_KG
# count              165.000000      165.000000           165.000000
# mean                 1.723515       13.096364           122.255152
# std                  6.001944       16.687354           222.849695
# min                  0.010000        0.100000             2.600000
# 25%                  0.120000        1.200000            17.300000
# 50%                  0.510000        5.400000            54.900000
# 75%                  1.330000       16.400000           127.500000
# max                 59.080000       84.800000          1564.400000

# %%
df.describe(include='all')
# Out:
#        Country  Total_Plastic_Waste_MT        Main_Sources  Recycling_Rate  \
# count      165              165.000000                 165      165.000000
# unique     165                     NaN                  10             NaN
# top      Nauru                     NaN  Consumer_Packaging             NaN
# freq         1                     NaN                 131             NaN
# mean       NaN                1.723515                 NaN       13.096364
# std        NaN                6.001944                 NaN       16.687354
# min        NaN                0.010000                 NaN        0.100000
# 25%        NaN                0.120000                 NaN        1.200000
# 50%        NaN                0.510000                 NaN        5.400000
# 75%        NaN                1.330000                 NaN       16.400000
# max        NaN               59.080000                 NaN       84.800000
#
#         Per_Capita_Waste_KG Coastal_Waste_Risk
# count            165.000000                165
# unique                  NaN                  4
# top                     NaN               High
# freq                    NaN                 74
# mean             122.255152                NaN
# std              222.849695                NaN
# min                2.600000                NaN
# 25%               17.300000                NaN
# 50%               54.900000                NaN
# 75%              127.500000                NaN
# max             1564.400000                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 165 non-null    object
#  1   Total_Plastic_Waste_MT  165 non-null    float64
#  2   Main_Sources            165 non-null    object
#  3   Recycling_Rate          165 non-null    float64
#  4   Per_Capita_Waste_KG     165 non-null    float64
#  5   Coastal_Waste_Risk      165 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 7.9+ KB

# %%
df.isna().sum()
# Out:
# Country                   0
# Total_Plastic_Waste_MT    0
# Main_Sources              0
# Recycling_Rate            0
# Per_Capita_Waste_KG       0
# Coastal_Waste_Risk        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                   0
# Total_Plastic_Waste_MT    0
# Main_Sources              0
# Recycling_Rate            0
# Per_Capita_Waste_KG       0
# Coastal_Waste_Risk        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Country                   165
# Total_Plastic_Waste_MT    122
# Main_Sources               10
# Recycling_Rate             83
# Per_Capita_Waste_KG       146
# Coastal_Waste_Risk          4
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
coastal_risk_counts = df['Coastal_Waste_Risk'].value_counts()
coastal_risk_counts
# Out:
# Coastal_Waste_Risk
# High         74
# Low          54
# Medium       33
# Very_High     4
# Name: count, dtype: int64

# %%
high_risk = df[df['Coastal_Waste_Risk']=='High']['Coastal_Waste_Risk'].count()
low_risk = df[df['Coastal_Waste_Risk']=='Low']['Coastal_Waste_Risk'].count()
medium_risk = df[df['Coastal_Waste_Risk']=='Medium']['Coastal_Waste_Risk'].count()
very_high_risk = df[df['Coastal_Waste_Risk']=='Very_High']['Coastal_Waste_Risk'].count()

# %%
plt.figure(figsize=(10,6))

index_values = [high_risk, low_risk, medium_risk, very_high_risk]
index_labels = ['High Risk', 'Low Risk', 'Medium Risk', 'Very High Risk']

plt.pie(index_values, labels = index_labels, autopct='%2.2f%%')

plt.title('Overall Coastal Risk Distribution', fontsize=20)

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.bar(coastal_risk_counts.index, coastal_risk_counts.values, color='teal', edgecolor='black')

plt.xticks(coastal_risk_counts.index, coastal_risk_counts.index, rotation = 90)

plt.xlabel('Coastal Risk Intensity', fontsize=17)
plt.ylabel('Total Counts in the Dataset', fontsize=17)

plt.title('Overall Distribution of Coastal Risk Intensity', fontsize=19)

plt.show()

# %%
main_sources_counts = df['Main_Sources'].value_counts()
main_sources_counts
# Out:
# Main_Sources
# Consumer_Packaging       131
# Industrial_Packaging      14
# Packaging_Consumer         5
# Packaging_Industrial       4
# Industrial_Consumer        4
# Food_Packaging             3
# Automotive_Packaging       1
# Packaging_Electronics      1
# Consumer_Goods             1
# Electronics_Packaging      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.bar(main_sources_counts.index, main_sources_counts.values, color='turquoise', edgecolor='black')

plt.xticks(main_sources_counts.index, main_sources_counts.index, rotation = 90)

plt.xlabel('Main Sources', fontsize=17)
plt.ylabel('Total Counts in the Dataset', fontsize=17)

plt.title('Overall Distribution of Main Sources', fontsize=19)

plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Chemin vers le fichier shapefile
path = '/content/ne_10m_admin_0_countries.shp'

# Lire le shapefile
world = gpd.read_file(path)

# Vérifier les colonnes du GeoDataFrame
print(world.columns)

# Fusionner avec votre DataFrame df
# Remplacer 'admin' par 'ADMIN'
world = world.merge(df, left_on='ADMIN', right_on='Country', how='left')

# Créer la figure et l'axe pour le tracé
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Tracer les limites des pays
world.boundary.plot(ax=ax)

# Tracer la carte avec la colonne 'Per_Capita_Waste_KG'
world.plot(column='Per_Capita_Waste_KG', ax=ax, legend=True, cmap='viridis',
           legend_kwds={'label': "Per Capita Waste (KG)",
                        'orientation': "horizontal"})

# Ajouter le titre
plt.title('World Distribution of Per Capita Waste (KG)', fontsize=16)
plt.show()
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=169)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Chemin vers le shapefile téléchargé
path = '/content/ne_10m_admin_0_countries.shp'

# Lire le shapefile
world = gpd.read_file(path)

# Fusionner avec votre DataFrame df
# Assurez-vous que df est déjà défini dans votre environnement
world = world.merge(df, left_on='ADMIN', right_on='Country', how='left')

# Créer la figure et l'axe pour le tracé
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Tracer les limites des pays
world.boundary.plot(ax=ax)

# Tracer la carte avec la colonne 'Recycling_Rate'
world.plot(column='Recycling_Rate', ax=ax, legend=True, cmap='viridis',
           legend_kwds={'label': "Recycling Rate",
                        'orientation': "horizontal"})

# Ajouter le titre
plt.title('World Distribution of Recycling Rate', fontsize=16)
plt.show()

# %%
# Chemin vers le shapefile téléchargé
path = '/content/ne_10m_admin_0_countries.shp'

# Lire le shapefile
world = gpd.read_file(path)

# Fusionner avec votre DataFrame df
# Assurez-vous que df est déjà défini dans votre environnement
world = world.merge(df, left_on='ADMIN', right_on='Country', how='left')

# Créer la figure et l'axe pour le tracé
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Tracer les limites des pays
world.boundary.plot(ax=ax)

# Tracer la carte avec la colonne 'Total_Plastic_Waste_MT'
world.plot(column='Total_Plastic_Waste_MT', ax=ax, legend=True, cmap='viridis',
           legend_kwds={'label': "Total Plastic Waste (MT)",
                        'orientation': "horizontal"})

# Ajouter le titre
plt.title('World Distribution of Total Plastic Waste (MT)', fontsize=16)
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Chemin vers le shapefile téléchargé
path = '/content/ne_10m_admin_0_countries.shp'

# Lire le shapefile
world = gpd.read_file(path)

# Fusionner avec votre DataFrame df
# Assurez-vous que df est déjà défini dans votre environnement
world = world.merge(df, left_on='ADMIN', right_on='Country', how='left')

# Créer la figure et l'axe pour le tracé
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Tracer les limites des pays
world.boundary.plot(ax=ax)

# Tracer la carte avec la colonne 'Coastal_Waste_Risk'
world.plot(column='Coastal_Waste_Risk', ax=ax, legend=True, cmap='viridis')

# Ajouter le titre
plt.title('World Distribution of Coastal Waste Risk', fontsize=16)
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Chemin vers le shapefile téléchargé
path = '/content/ne_10m_admin_0_countries.shp'

# Lire le shapefile
world = gpd.read_file(path)

# Fusionner avec votre DataFrame df
# Assurez-vous que df est déjà défini dans votre environnement
world = world.merge(df, left_on='ADMIN', right_on='Country', how='left')

# Créer la figure et l'axe pour le tracé
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Tracer les limites des pays
world.boundary.plot(ax=ax)

# Tracer la carte avec la colonne 'Main_Sources'
world.plot(column='Main_Sources', ax=ax, legend=True, cmap='viridis')

# Ajouter le titre
plt.title('World Distribution of Main Sources', fontsize=16)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
df['Coastal_Waste_Risk'] = LabelEncoder().fit_transform(df['Coastal_Waste_Risk'])
df['Coastal_Waste_Risk']
# Out:
# 0      0
# 1      2
# 2      0
# 3      2
# 4      1
#       ..
# 160    0
# 161    0
# 162    0
# 163    0
# 164    0
# Name: Coastal_Waste_Risk, Length: 165, dtype: int64

# %%
df['Main_Sources'] = LabelEncoder().fit_transform(df['Main_Sources'])
df['Main_Sources']
# Out:
# 0      9
# 1      7
# 2      1
# 3      8
# 4      0
#       ..
# 160    2
# 161    2
# 162    2
# 163    2
# 164    2
# Name: Main_Sources, Length: 165, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
features = df.drop(columns=['Country', 'Main_Sources'])
target = df['Main_Sources']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=29)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=29)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=29)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)
y_pred_rf
# Out:
# array([2, 2, 9, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
y_test
# Out:
# 100    2
# 137    2
# 31     6
# 93     2
# 124    2
# 39     6
# 160    2
# 2      1
# 155    2
# 63     2
# 147    2
# 126    2
# 136    2
# 127    2
# 120    2
# 87     2
# 45     2
# 53     5
# 161    2
# 89     2
# 157    2
# 28     2
# 27     2
# 73     2
# 110    2
# 90     2
# 149    2
# 48     5
# 10     2
# 7      5
# 128    2
# 125    2
# 98     2
# Name: Main_Sources, dtype: int64

# %%
accuracy = accuracy_score(y_test, y_pred_rf)
accuracy
# Out:
# 0.8181818181818182

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
features = df.drop(columns=['Country', 'Coastal_Waste_Risk'])
target = df['Coastal_Waste_Risk']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.05, random_state=29)

# %%
catboost_model = CatBoostClassifier(iterations=500, learning_rate=0.1, depth=6, verbose=False, random_state=29)
catboost_model.fit(X_train, y_train)

# %%
y_pred_cb = catboost_model.predict(X_test)
y_pred_cb
# Out:
# array([[0],
#        [1],
#        [1],
#        [0],
#        [1],
#        [1],
#        [0],
#        [0],
#        [0]])

# %%
y_test
# Out:
# 100    1
# 137    2
# 31     1
# 93     0
# 124    1
# 39     1
# 160    0
# 2      0
# 155    0
# Name: Coastal_Waste_Risk, dtype: int64

# %%
accuracy = accuracy_score(y_test, y_pred_cb)
print(accuracy)
# Out:
# 0.7777777777777778

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,6))
corr_matrix = df.drop(columns=['Country']).corr()
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt='.2f')
plt.title('Correlation Heatmap', fontsize=23)
plt.show()
